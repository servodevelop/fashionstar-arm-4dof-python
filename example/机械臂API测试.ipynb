# %% [markdown]
# ## 导入依赖

# %%
import sys
sys.path.append('../src/')

import math
from fs_arm_4dof import Arm4DoF
from config import *

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# ## 创建机械臂对象

# %%
arm = Arm4DoF('/dev/ttyUSB2')
# arm = Arm4DoF()

# %% [markdown]
# ## 机械臂位姿初始化

# %%
arm.init_pose()

# %% [markdown]
# ## 设置关节弧度

# %% [markdown]
# 设置单个关节的弧度

# %%
arm.set_joint({JOINT1:math.pi/2}, wait=True)

# %% [markdown]
# 设置多个关节的弧度

# %%
thetas = {
    JOINT1:0, 
    JOINT2:-3*math.pi/4,
    JOINT3:math.pi/2,
    JOINT4:math.pi/4}

arm.set_joint(thetas, wait=True)

# %% [markdown]
# 测试设置关节弧度2(带minimum jerk 算法版本)

# %%
# thetas = arm.get_thetas(theta_type=dict)
# thetas[JOINT1] = math.pi/2
thetas = {0: 0.7853981633974483,
 1: -1.6615195583843205,
 2: 0.6007119150538508,
 3: 1.0608076433304698}
theta_seq_dict = arm.set_joint2(thetas, 1)
# Out:
# joint0 theta_arr: [0.00000000e+00 7.84220571e-09 6.26435110e-08 ... 7.85398419e-01
#  7.85398474e-01 7.85398483e-01]
# joint1 theta_arr: [-2.3561945  -2.35619449 -2.35619444 ... -1.66152195 -1.66152191
#  -1.66152191]
# joint2 theta_arr: [1.57079637 1.57079636 1.57079629 ... 0.60071131 0.60071124 0.60071123]
# joint3 theta_arr: [0.78539819 0.78539819 0.78539821 ... 1.06080691 1.06080693 1.06080693]

# %%
theta_seq_dict
# Out:
# {0: array([0.000e+00, 1.000e-03, 2.000e-03, ..., 1.998e+00, 1.999e+00,
#         2.000e+00]),
#  1: array([0.000e+00, 1.000e-03, 2.000e-03, ..., 1.998e+00, 1.999e+00,
#         2.000e+00]),
#  2: array([0.000e+00, 1.000e-03, 2.000e-03, ..., 1.998e+00, 1.999e+00,
#         2.000e+00]),
#  3: array([0.000e+00, 1.000e-03, 2.000e-03, ..., 1.998e+00, 1.999e+00,
#         2.000e+00])}

# %%
theta_arr = arm.get_thetas()
theta_arr
# Out:
# [1.5707963267948966, 0.0, 2.0, 1.5707963267948966]

# %% [markdown]
# ## 获取当前关节的弧度

# %%
arm.get_thetas()
# Out:
# [-0.0, -2.356194490192345, 1.5707963267948966, 0.7853981633974483]

# %%
arm.set_joint({JOINT4:0.65})

# %% [markdown]
# ## 逆向运动学测试

# %%
ret, thetas = arm.inverse_kinematics([5, 0, 5])
print('逆向运动学是否有解: {}'.format(ret))
print('逆向运动学求解得到的关节弧度: {}'.format(thetas))
# Out:
# 逆向运动学是否有解: True
# 逆向运动学求解得到的关节弧度: [0.0, -2.4973291069937735, 1.8145686544950745, 0.682760452498699]

# %% [markdown]
# ## 控制末端移动

# %%
arm.move([5, 0, 5])

# %%
arm.move([6, 6, 10])

# %%
theta4_offset = -0.18

# %%
arm.move2([5, 5, 10], 2, theta4_offset=theta4_offset)

# %% [markdown]
# 测试动作组1

# %%
arm.move2([5, -5, 10], 1, theta4_offset=theta4_offset)
arm.move2([5, -5, 5], 1, theta4_offset=theta4_offset)
arm.move2([5, 5, 5], 1, theta4_offset=theta4_offset)
arm.move2([2, 2, 5], 1, theta4_offset=theta4_offset)

# %% [markdown]
# 测试动作组2

# %%
arm.move2([5, -5, 10], 1, theta4_offset=theta4_offset)
arm.move2([5, 5, 5], 1, theta4_offset=theta4_offset)
arm.move2([5, 5, 10], 1, theta4_offset=theta4_offset)
arm.move2([5, -5, 5], 1, theta4_offset=theta4_offset)
arm.move2([5, 0, 5], 1, theta4_offset=theta4_offset)

# %% [markdown]
# ## 关节空间下的线性插补

# %% [markdown]
# 从A点移动到B点的时候,连杆LINK45始终与桌面保持平行

# %%
arm.linear_interpolation([6, 6, 10])
# Out:
# INFO:root:设置关节弧度, 关节#1  弧度 0.0231 角度 1.3
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x97 0xff 0x0d 0x00 0x00 0x00 0x10
# INFO:root:设置关节弧度, 关节#2  弧度 -2.4727 角度 -141.7
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0x29 0xfe 0x0d 0x00 0x00 0x00 0xa2
# INFO:root:设置关节弧度, 关节#3  弧度 1.7789 角度 101.9
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0xb8 0xfd 0x15 0x00 0x00 0x00 0x39
# INFO:root:设置关节弧度, 关节#4  弧度 0.6939 角度 39.8
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0x5d 0xfe 0x06 0x00 0x00 0x00 0xd1
# INFO:root:设置关节弧度, 关节#1  弧度 0.0462 角度 2.6
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x8a 0xff 0x0d 0x00 0x00 0x00 0x03
# INFO:root:设置关节弧度, 关节#2  弧度 -2.4482 角度 -140.3
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0x37 0xfe 0x0d 0x00 0x00 0x00 0xb0
# INFO:root:设置关节弧度, 关节#3  弧度 1.7432 角度 99.9
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0xcd 0xfd 0x15 0x00 0x00 0x00 0x4e
# INFO:root:设置关节弧度, 关节#4  弧度 0.7050 角度 40.4
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0x57 0xfe 0x06 0x00 0x00 0x00 0xcb
# INFO:root:设置关节弧度, 关节#1  弧度 0.0693 角度 4.0
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x7d 0xff 0x0d 0x00 0x00 0x00 0xf6
# INFO:root:设置关节弧度, 关节#2  弧度 -2.4236 角度 -138.9
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0x45 0xfe 0x0d 0x00 0x00 0x00 0xbe
# INFO:root:设置关节弧度, 关节#3  弧度 1.7075 角度 97.8
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0xe3 0xfd 0x15 0x00 0x00 0x00 0x64
# INFO:root:设置关节弧度, 关节#4  弧度 0.7161 角度 41.0
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0x50 0xfe 0x06 0x00 0x00 0x00 0xc4
# INFO:root:设置关节弧度, 关节#1  弧度 0.0924 角度 5.3
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x70 0xff 0x0d 0x00 0x00 0x00 0xe9
# INFO:root:设置关节弧度, 关节#2  弧度 -2.3990 角度 -137.5
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0x53 0xfe 0x0d 0x00 0x00 0x00 0xcc
# INFO:root:设置关节弧度, 关节#3  弧度 1.6718 角度 95.8
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0xf8 0xfd 0x15 0x00 0x00 0x00 0x79
# INFO:root:设置关节弧度, 关节#4  弧度 0.7272 角度 41.7
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0x4a 0xfe 0x06 0x00 0x00 0x00 0xbe
# INFO:root:设置关节弧度, 关节#1  弧度 0.1155 角度 6.6
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x62 0xff 0x0d 0x00 0x00 0x00 0xdb
# INFO:root:设置关节弧度, 关节#2  弧度 -2.3744 角度 -136.0
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0x61 0xfe 0x0d 0x00 0x00 0x00 0xda
# INFO:root:设置关节弧度, 关节#3  弧度 1.6361 角度 93.7
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0x0d 0xfe 0x15 0x00 0x00 0x00 0x8f
# INFO:root:设置关节弧度, 关节#4  弧度 0.7384 角度 42.3
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0x43 0xfe 0x06 0x00 0x00 0x00 0xb7
# INFO:root:设置关节弧度, 关节#1  弧度 0.1386 角度 7.9
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x55 0xff 0x0d 0x00 0x00 0x00 0xce
# INFO:root:设置关节弧度, 关节#2  弧度 -2.3498 角度 -134.6
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0x6f 0xfe 0x0d 0x00 0x00 0x00 0xe8
# INFO:root:设置关节弧度, 关节#3  弧度 1.6004 角度 91.7
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0x23 0xfe 0x15 0x00 0x00 0x00 0xa5
# INFO:root:设置关节弧度, 关节#4  弧度 0.7495 角度 42.9
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0x3d 0xfe 0x06 0x00 0x00 0x00 0xb1
# INFO:root:设置关节弧度, 关节#1  弧度 0.1617 角度 9.3
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x48 0xff 0x0d 0x00 0x00 0x00 0xc1
# INFO:root:设置关节弧度, 关节#2  弧度 -2.3253 角度 -133.2
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0x7d 0xfe 0x0d 0x00 0x00 0x00 0xf6
# INFO:root:设置关节弧度, 关节#3  弧度 1.5647 角度 89.6
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0x38 0xfe 0x15 0x00 0x00 0x00 0xba
# INFO:root:设置关节弧度, 关节#4  弧度 0.7606 角度 43.6
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0x36 0xfe 0x06 0x00 0x00 0x00 0xaa
# INFO:root:设置关节弧度, 关节#1  弧度 0.1848 角度 10.6
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x3b 0xff 0x0d 0x00 0x00 0x00 0xb4
# INFO:root:设置关节弧度, 关节#2  弧度 -2.3007 角度 -131.8
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0x8b 0xfe 0x0d 0x00 0x00 0x00 0x04
# INFO:root:设置关节弧度, 关节#3  弧度 1.5290 角度 87.6
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0x4e 0xfe 0x15 0x00 0x00 0x00 0xd0
# INFO:root:设置关节弧度, 关节#4  弧度 0.7717 角度 44.2
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0x30 0xfe 0x06 0x00 0x00 0x00 0xa4
# INFO:root:设置关节弧度, 关节#1  弧度 0.2079 角度 11.9
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x2e 0xff 0x0d 0x00 0x00 0x00 0xa7
# INFO:root:设置关节弧度, 关节#2  弧度 -2.2761 角度 -130.4
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0x99 0xfe 0x0d 0x00 0x00 0x00 0x12
# INFO:root:设置关节弧度, 关节#3  弧度 1.4933 角度 85.6
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0x63 0xfe 0x15 0x00 0x00 0x00 0xe5
# INFO:root:设置关节弧度, 关节#4  弧度 0.7828 角度 44.9
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0x29 0xfe 0x06 0x00 0x00 0x00 0x9d
# INFO:root:设置关节弧度, 关节#1  弧度 0.2310 角度 13.2
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x21 0xff 0x0d 0x00 0x00 0x00 0x9a
# INFO:root:设置关节弧度, 关节#2  弧度 -2.2515 角度 -129.0
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0xa7 0xfe 0x0d 0x00 0x00 0x00 0x20
# INFO:root:设置关节弧度, 关节#3  弧度 1.4576 角度 83.5
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0x78 0xfe 0x15 0x00 0x00 0x00 0xfa
# INFO:root:设置关节弧度, 关节#4  弧度 0.7940 角度 45.5
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0x23 0xfe 0x06 0x00 0x00 0x00 0x97
# INFO:root:设置关节弧度, 关节#1  弧度 0.2541 角度 14.6
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x14 0xff 0x0d 0x00 0x00 0x00 0x8d
# INFO:root:设置关节弧度, 关节#2  弧度 -2.2269 角度 -127.6
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0xb5 0xfe 0x0d 0x00 0x00 0x00 0x2e
# INFO:root:设置关节弧度, 关节#3  弧度 1.4219 角度 81.5
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0x8e 0xfe 0x15 0x00 0x00 0x00 0x10
# INFO:root:设置关节弧度, 关节#4  弧度 0.8051 角度 46.1
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0x1d 0xfe 0x06 0x00 0x00 0x00 0x91
# INFO:root:设置关节弧度, 关节#1  弧度 0.2772 角度 15.9
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x07 0xff 0x0d 0x00 0x00 0x00 0x80
# INFO:root:设置关节弧度, 关节#2  弧度 -2.2023 角度 -126.2
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0xc3 0xfe 0x0d 0x00 0x00 0x00 0x3c
# INFO:root:设置关节弧度, 关节#3  弧度 1.3861 角度 79.4
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0xa3 0xfe 0x15 0x00 0x00 0x00 0x25
# INFO:root:设置关节弧度, 关节#4  弧度 0.8162 角度 46.8
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0x16 0xfe 0x06 0x00 0x00 0x00 0x8a
# INFO:root:设置关节弧度, 关节#1  弧度 0.3003 角度 17.2
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0xf9 0xfe 0x0d 0x00 0x00 0x00 0x71
# INFO:root:设置关节弧度, 关节#2  弧度 -2.1778 角度 -124.8
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0xd1 0xfe 0x0d 0x00 0x00 0x00 0x4a
# INFO:root:设置关节弧度, 关节#3  弧度 1.3504 角度 77.4
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0xb8 0xfe 0x15 0x00 0x00 0x00 0x3a
# INFO:root:设置关节弧度, 关节#4  弧度 0.8273 角度 47.4
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0x10 0xfe 0x06 0x00 0x00 0x00 0x84
# INFO:root:设置关节弧度, 关节#1  弧度 0.3234 角度 18.5
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0xec 0xfe 0x0d 0x00 0x00 0x00 0x64
# INFO:root:设置关节弧度, 关节#2  弧度 -2.1532 角度 -123.4
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0xdf 0xfe 0x0d 0x00 0x00 0x00 0x58
# INFO:root:设置关节弧度, 关节#3  弧度 1.3147 角度 75.3
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0xce 0xfe 0x15 0x00 0x00 0x00 0x50
# INFO:root:设置关节弧度, 关节#4  弧度 0.8384 角度 48.0
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0x09 0xfe 0x06 0x00 0x00 0x00 0x7d
# INFO:root:设置关节弧度, 关节#1  弧度 0.3465 角度 19.9
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0xdf 0xfe 0x0d 0x00 0x00 0x00 0x57
# INFO:root:设置关节弧度, 关节#2  弧度 -2.1286 角度 -122.0
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0xec 0xfe 0x0d 0x00 0x00 0x00 0x65
# INFO:root:设置关节弧度, 关节#3  弧度 1.2790 角度 73.3
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0xe3 0xfe 0x15 0x00 0x00 0x00 0x65
# INFO:root:设置关节弧度, 关节#4  弧度 0.8495 角度 48.7
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0x03 0xfe 0x06 0x00 0x00 0x00 0x77
# INFO:root:设置关节弧度, 关节#1  弧度 0.3696 角度 21.2
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0xd2 0xfe 0x0d 0x00 0x00 0x00 0x4a
# INFO:root:设置关节弧度, 关节#2  弧度 -2.1040 角度 -120.6
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0xfa 0xfe 0x0d 0x00 0x00 0x00 0x73
# INFO:root:设置关节弧度, 关节#3  弧度 1.2433 角度 71.2
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0xf8 0xfe 0x15 0x00 0x00 0x00 0x7a
# INFO:root:设置关节弧度, 关节#4  弧度 0.8607 角度 49.3
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0xfc 0xfd 0x06 0x00 0x00 0x00 0x6f
# INFO:root:设置关节弧度, 关节#1  弧度 0.3927 角度 22.5
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0xc5 0xfe 0x0d 0x00 0x00 0x00 0x3d
# INFO:root:设置关节弧度, 关节#2  弧度 -2.0794 角度 -119.1
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0x08 0xff 0x0d 0x00 0x00 0x00 0x82
# INFO:root:设置关节弧度, 关节#3  弧度 1.2076 角度 69.2
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0x0e 0xff 0x15 0x00 0x00 0x00 0x91
# INFO:root:设置关节弧度, 关节#4  弧度 0.8718 角度 49.9
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0xf6 0xfd 0x06 0x00 0x00 0x00 0x69
# INFO:root:设置关节弧度, 关节#1  弧度 0.4158 角度 23.8
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0xb8 0xfe 0x0d 0x00 0x00 0x00 0x30
# INFO:root:设置关节弧度, 关节#2  弧度 -2.0548 角度 -117.7
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0x16 0xff 0x0d 0x00 0x00 0x00 0x90
# INFO:root:设置关节弧度, 关节#3  弧度 1.1719 角度 67.1
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0x23 0xff 0x15 0x00 0x00 0x00 0xa6
# INFO:root:设置关节弧度, 关节#4  弧度 0.8829 角度 50.6
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0xef 0xfd 0x06 0x00 0x00 0x00 0x62
# INFO:root:设置关节弧度, 关节#1  弧度 0.4389 角度 25.1
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0xab 0xfe 0x0d 0x00 0x00 0x00 0x23
# INFO:root:设置关节弧度, 关节#2  弧度 -2.0303 角度 -116.3
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0x24 0xff 0x0d 0x00 0x00 0x00 0x9e
# INFO:root:设置关节弧度, 关节#3  弧度 1.1362 角度 65.1
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0x39 0xff 0x15 0x00 0x00 0x00 0xbc
# INFO:root:设置关节弧度, 关节#4  弧度 0.8940 角度 51.2
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0xe9 0xfd 0x06 0x00 0x00 0x00 0x5c
# INFO:root:设置关节弧度, 关节#1  弧度 0.4620 角度 26.5
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x9e 0xfe 0x0d 0x00 0x00 0x00 0x16
# INFO:root:设置关节弧度, 关节#2  弧度 -2.0057 角度 -114.9
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0x32 0xff 0x0d 0x00 0x00 0x00 0xac
# INFO:root:设置关节弧度, 关节#3  弧度 1.1005 角度 63.1
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0x4e 0xff 0x15 0x00 0x00 0x00 0xd1
# INFO:root:设置关节弧度, 关节#4  弧度 0.9051 角度 51.9
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0xe2 0xfd 0x06 0x00 0x00 0x00 0x55
# INFO:root:设置关节弧度, 关节#1  弧度 0.4851 角度 27.8
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x90 0xfe 0x0d 0x00 0x00 0x00 0x08
# INFO:root:设置关节弧度, 关节#2  弧度 -1.9811 角度 -113.5
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0x40 0xff 0x0d 0x00 0x00 0x00 0xba
# INFO:root:设置关节弧度, 关节#3  弧度 1.0648 角度 61.0
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0x63 0xff 0x15 0x00 0x00 0x00 0xe6
# INFO:root:设置关节弧度, 关节#4  弧度 0.9163 角度 52.5
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0xdc 0xfd 0x06 0x00 0x00 0x00 0x4f
# INFO:root:设置关节弧度, 关节#1  弧度 0.5082 角度 29.1
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x83 0xfe 0x0d 0x00 0x00 0x00 0xfb
# INFO:root:设置关节弧度, 关节#2  弧度 -1.9565 角度 -112.1
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0x4e 0xff 0x0d 0x00 0x00 0x00 0xc8
# INFO:root:设置关节弧度, 关节#3  弧度 1.0291 角度 59.0
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0x79 0xff 0x15 0x00 0x00 0x00 0xfc
# INFO:root:设置关节弧度, 关节#4  弧度 0.9274 角度 53.1
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0xd5 0xfd 0x06 0x00 0x00 0x00 0x48
# INFO:root:设置关节弧度, 关节#1  弧度 0.5313 角度 30.4
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x76 0xfe 0x0d 0x00 0x00 0x00 0xee
# INFO:root:设置关节弧度, 关节#2  弧度 -1.9319 角度 -110.7
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0x5c 0xff 0x0d 0x00 0x00 0x00 0xd6
# INFO:root:设置关节弧度, 关节#3  弧度 0.9934 角度 56.9
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0x8e 0xff 0x15 0x00 0x00 0x00 0x11
# INFO:root:设置关节弧度, 关节#4  弧度 0.9385 角度 53.8
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0xcf 0xfd 0x06 0x00 0x00 0x00 0x42
# INFO:root:设置关节弧度, 关节#1  弧度 0.5544 角度 31.8
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x69 0xfe 0x0d 0x00 0x00 0x00 0xe1
# INFO:root:设置关节弧度, 关节#2  弧度 -1.9073 角度 -109.3
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0x6a 0xff 0x0d 0x00 0x00 0x00 0xe4
# INFO:root:设置关节弧度, 关节#3  弧度 0.9577 角度 54.9
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0xa3 0xff 0x15 0x00 0x00 0x00 0x26
# INFO:root:设置关节弧度, 关节#4  弧度 0.9496 角度 54.4
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0xc8 0xfd 0x06 0x00 0x00 0x00 0x3b
# INFO:root:设置关节弧度, 关节#1  弧度 0.5775 角度 33.1
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x5c 0xfe 0x0d 0x00 0x00 0x00 0xd4
# INFO:root:设置关节弧度, 关节#2  弧度 -1.8828 角度 -107.9
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0x78 0xff 0x0d 0x00 0x00 0x00 0xf2
# INFO:root:设置关节弧度, 关节#3  弧度 0.9220 角度 52.8
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0xb9 0xff 0x15 0x00 0x00 0x00 0x3c
# INFO:root:设置关节弧度, 关节#4  弧度 0.9607 角度 55.0
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0xc2 0xfd 0x06 0x00 0x00 0x00 0x35
# INFO:root:设置关节弧度, 关节#1  弧度 0.6006 角度 34.4
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x4f 0xfe 0x0d 0x00 0x00 0x00 0xc7
# INFO:root:设置关节弧度, 关节#2  弧度 -1.8582 角度 -106.5
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0x86 0xff 0x0d 0x00 0x00 0x00 0x00
# INFO:root:设置关节弧度, 关节#3  弧度 0.8863 角度 50.8
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0xce 0xff 0x15 0x00 0x00 0x00 0x51
# INFO:root:设置关节弧度, 关节#4  弧度 0.9719 角度 55.7
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0xbb 0xfd 0x06 0x00 0x00 0x00 0x2e
# INFO:root:设置关节弧度, 关节#1  弧度 0.6237 角度 35.7
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x42 0xfe 0x0d 0x00 0x00 0x00 0xba
# INFO:root:设置关节弧度, 关节#2  弧度 -1.8336 角度 -105.1
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0x94 0xff 0x0d 0x00 0x00 0x00 0x0e
# INFO:root:设置关节弧度, 关节#3  弧度 0.8506 角度 48.7
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0xe3 0xff 0x15 0x00 0x00 0x00 0x66
# INFO:root:设置关节弧度, 关节#4  弧度 0.9830 角度 56.3
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0xb5 0xfd 0x06 0x00 0x00 0x00 0x28
# INFO:root:设置关节弧度, 关节#1  弧度 0.6468 角度 37.1
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x35 0xfe 0x0d 0x00 0x00 0x00 0xad
# INFO:root:设置关节弧度, 关节#2  弧度 -1.8090 角度 -103.6
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0xa2 0xff 0x0d 0x00 0x00 0x00 0x1c
# INFO:root:设置关节弧度, 关节#3  弧度 0.8149 角度 46.7
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0xf9 0xff 0x15 0x00 0x00 0x00 0x7c
# INFO:root:设置关节弧度, 关节#4  弧度 0.9941 角度 57.0
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0xae 0xfd 0x06 0x00 0x00 0x00 0x21
# INFO:root:设置关节弧度, 关节#1  弧度 0.6699 角度 38.4
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x27 0xfe 0x0d 0x00 0x00 0x00 0x9f
# INFO:root:设置关节弧度, 关节#2  弧度 -1.7844 角度 -102.2
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0xaf 0xff 0x0d 0x00 0x00 0x00 0x29
# INFO:root:设置关节弧度, 关节#3  弧度 0.7792 角度 44.6
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0x0d 0x00 0x15 0x00 0x00 0x00 0x91
# INFO:root:设置关节弧度, 关节#4  弧度 1.0052 角度 57.6
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0xa8 0xfd 0x06 0x00 0x00 0x00 0x1b
# INFO:root:设置关节弧度, 关节#1  弧度 0.6930 角度 39.7
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x1a 0xfe 0x0d 0x00 0x00 0x00 0x92
# INFO:root:设置关节弧度, 关节#2  弧度 -1.7599 角度 -100.8
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0xbd 0xff 0x0d 0x00 0x00 0x00 0x37
# INFO:root:设置关节弧度, 关节#3  弧度 0.7435 角度 42.6
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0x23 0x00 0x15 0x00 0x00 0x00 0xa7
# INFO:root:设置关节弧度, 关节#4  弧度 1.0163 角度 58.2
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0xa1 0xfd 0x06 0x00 0x00 0x00 0x14
# INFO:root:设置关节弧度, 关节#1  弧度 0.7161 角度 41.0
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x0d 0xfe 0x0d 0x00 0x00 0x00 0x85
# INFO:root:设置关节弧度, 关节#2  弧度 -1.7353 角度 -99.4
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0xcb 0xff 0x0d 0x00 0x00 0x00 0x45
# INFO:root:设置关节弧度, 关节#3  弧度 0.7078 角度 40.6
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0x38 0x00 0x15 0x00 0x00 0x00 0xbc
# INFO:root:设置关节弧度, 关节#4  弧度 1.0275 角度 58.9
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0x9b 0xfd 0x06 0x00 0x00 0x00 0x0e
# INFO:root:设置关节弧度, 关节#1  弧度 0.7392 角度 42.4
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x00 0xfe 0x0d 0x00 0x00 0x00 0x78
# INFO:root:设置关节弧度, 关节#2  弧度 -1.7107 角度 -98.0
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0xd9 0xff 0x0d 0x00 0x00 0x00 0x53
# INFO:root:设置关节弧度, 关节#3  弧度 0.6721 角度 38.5
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0x4d 0x00 0x15 0x00 0x00 0x00 0xd1
# INFO:root:设置关节弧度, 关节#4  弧度 1.0386 角度 59.5
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0x95 0xfd 0x06 0x00 0x00 0x00 0x08
# INFO:root:设置关节弧度, 关节#1  弧度 0.7623 角度 43.7
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0xf3 0xfd 0x0d 0x00 0x00 0x00 0x6a
# INFO:root:设置关节弧度, 关节#2  弧度 -1.6861 角度 -96.6
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0xe7 0xff 0x0d 0x00 0x00 0x00 0x61
# INFO:root:设置关节弧度, 关节#3  弧度 0.6364 角度 36.5
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0x63 0x00 0x15 0x00 0x00 0x00 0xe7
# INFO:root:设置关节弧度, 关节#4  弧度 1.0497 角度 60.1
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0x8e 0xfd 0x06 0x00 0x00 0x00 0x01
# INFO:root:设置关节弧度, 关节#1  弧度 0.7854 角度 45.0
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0xe6 0xfd 0x0d 0x00 0x00 0x00 0x5d
# INFO:root:设置关节弧度, 关节#2  弧度 -1.6615 角度 -95.2
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0xf5 0xff 0x0d 0x00 0x00 0x00 0x6f
# INFO:root:设置关节弧度, 关节#3  弧度 0.6007 角度 34.4
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0x78 0x00 0x15 0x00 0x00 0x00 0xfc
# INFO:root:设置关节弧度, 关节#4  弧度 1.0608 角度 60.8
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0x88 0xfd 0x06 0x00 0x00 0x00 0xfb
# INFO:root:设置关节弧度, 关节#1  弧度 0.7854 角度 45.0
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0xe6 0xfd 0x00 0x00 0x00 0x00 0x50
# INFO:root:设置关节弧度, 关节#2  弧度 -1.6615 角度 -95.2
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0xf5 0xff 0x00 0x00 0x00 0x00 0x62
# INFO:root:设置关节弧度, 关节#3  弧度 0.6007 角度 34.4
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0x78 0x00 0x00 0x00 0x00 0x00 0xe7
# INFO:root:设置关节弧度, 关节#4  弧度 1.0608 角度 60.8
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0x88 0xfd 0x00 0x00 0x00 0x00 0xf5

# %%
arm.linear_interpolation([5, 0, 5])
# Out:
# INFO:root:设置关节弧度, 关节#1  弧度 0.7623 角度 43.7
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0xf3 0xfd 0x0d 0x00 0x00 0x00 0x6a
# INFO:root:设置关节弧度, 关节#2  弧度 -1.6861 角度 -96.6
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0xe7 0xff 0x0d 0x00 0x00 0x00 0x61
# INFO:root:设置关节弧度, 关节#3  弧度 0.6364 角度 36.5
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0x63 0x00 0x15 0x00 0x00 0x00 0xe7
# INFO:root:设置关节弧度, 关节#4  弧度 1.0497 角度 60.1
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0x8e 0xfd 0x06 0x00 0x00 0x00 0x01
# INFO:root:设置关节弧度, 关节#1  弧度 0.7392 角度 42.4
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x00 0xfe 0x0d 0x00 0x00 0x00 0x78
# INFO:root:设置关节弧度, 关节#2  弧度 -1.7107 角度 -98.0
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0xd9 0xff 0x0d 0x00 0x00 0x00 0x53
# INFO:root:设置关节弧度, 关节#3  弧度 0.6721 角度 38.5
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0x4d 0x00 0x15 0x00 0x00 0x00 0xd1
# INFO:root:设置关节弧度, 关节#4  弧度 1.0386 角度 59.5
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0x95 0xfd 0x06 0x00 0x00 0x00 0x08
# INFO:root:设置关节弧度, 关节#1  弧度 0.7161 角度 41.0
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x0d 0xfe 0x0d 0x00 0x00 0x00 0x85
# INFO:root:设置关节弧度, 关节#2  弧度 -1.7353 角度 -99.4
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0xcb 0xff 0x0d 0x00 0x00 0x00 0x45
# INFO:root:设置关节弧度, 关节#3  弧度 0.7078 角度 40.6
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0x38 0x00 0x15 0x00 0x00 0x00 0xbc
# INFO:root:设置关节弧度, 关节#4  弧度 1.0275 角度 58.9
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0x9b 0xfd 0x06 0x00 0x00 0x00 0x0e
# INFO:root:设置关节弧度, 关节#1  弧度 0.6930 角度 39.7
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x1a 0xfe 0x0d 0x00 0x00 0x00 0x92
# INFO:root:设置关节弧度, 关节#2  弧度 -1.7599 角度 -100.8
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0xbd 0xff 0x0d 0x00 0x00 0x00 0x37
# INFO:root:设置关节弧度, 关节#3  弧度 0.7435 角度 42.6
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0x23 0x00 0x15 0x00 0x00 0x00 0xa7
# INFO:root:设置关节弧度, 关节#4  弧度 1.0163 角度 58.2
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0xa1 0xfd 0x06 0x00 0x00 0x00 0x14
# INFO:root:设置关节弧度, 关节#1  弧度 0.6699 角度 38.4
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x27 0xfe 0x0d 0x00 0x00 0x00 0x9f
# INFO:root:设置关节弧度, 关节#2  弧度 -1.7844 角度 -102.2
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0xaf 0xff 0x0d 0x00 0x00 0x00 0x29
# INFO:root:设置关节弧度, 关节#3  弧度 0.7792 角度 44.6
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0x0d 0x00 0x15 0x00 0x00 0x00 0x91
# INFO:root:设置关节弧度, 关节#4  弧度 1.0052 角度 57.6
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0xa8 0xfd 0x06 0x00 0x00 0x00 0x1b
# INFO:root:设置关节弧度, 关节#1  弧度 0.6468 角度 37.1
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x35 0xfe 0x0d 0x00 0x00 0x00 0xad
# INFO:root:设置关节弧度, 关节#2  弧度 -1.8090 角度 -103.6
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0xa2 0xff 0x0d 0x00 0x00 0x00 0x1c
# INFO:root:设置关节弧度, 关节#3  弧度 0.8149 角度 46.7
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0xf9 0xff 0x15 0x00 0x00 0x00 0x7c
# INFO:root:设置关节弧度, 关节#4  弧度 0.9941 角度 57.0
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0xae 0xfd 0x06 0x00 0x00 0x00 0x21
# INFO:root:设置关节弧度, 关节#1  弧度 0.6237 角度 35.7
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x42 0xfe 0x0d 0x00 0x00 0x00 0xba
# INFO:root:设置关节弧度, 关节#2  弧度 -1.8336 角度 -105.1
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0x94 0xff 0x0d 0x00 0x00 0x00 0x0e
# INFO:root:设置关节弧度, 关节#3  弧度 0.8506 角度 48.7
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0xe3 0xff 0x15 0x00 0x00 0x00 0x66
# INFO:root:设置关节弧度, 关节#4  弧度 0.9830 角度 56.3
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0xb5 0xfd 0x06 0x00 0x00 0x00 0x28
# INFO:root:设置关节弧度, 关节#1  弧度 0.6006 角度 34.4
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x4f 0xfe 0x0d 0x00 0x00 0x00 0xc7
# INFO:root:设置关节弧度, 关节#2  弧度 -1.8582 角度 -106.5
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0x86 0xff 0x0d 0x00 0x00 0x00 0x00
# INFO:root:设置关节弧度, 关节#3  弧度 0.8863 角度 50.8
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0xce 0xff 0x15 0x00 0x00 0x00 0x51
# INFO:root:设置关节弧度, 关节#4  弧度 0.9719 角度 55.7
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0xbb 0xfd 0x06 0x00 0x00 0x00 0x2e
# INFO:root:设置关节弧度, 关节#1  弧度 0.5775 角度 33.1
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x5c 0xfe 0x0d 0x00 0x00 0x00 0xd4
# INFO:root:设置关节弧度, 关节#2  弧度 -1.8828 角度 -107.9
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0x78 0xff 0x0d 0x00 0x00 0x00 0xf2
# INFO:root:设置关节弧度, 关节#3  弧度 0.9220 角度 52.8
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0xb9 0xff 0x15 0x00 0x00 0x00 0x3c
# INFO:root:设置关节弧度, 关节#4  弧度 0.9607 角度 55.0
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0xc2 0xfd 0x06 0x00 0x00 0x00 0x35
# INFO:root:设置关节弧度, 关节#1  弧度 0.5544 角度 31.8
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x69 0xfe 0x0d 0x00 0x00 0x00 0xe1
# INFO:root:设置关节弧度, 关节#2  弧度 -1.9073 角度 -109.3
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0x6a 0xff 0x0d 0x00 0x00 0x00 0xe4
# INFO:root:设置关节弧度, 关节#3  弧度 0.9577 角度 54.9
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0xa3 0xff 0x15 0x00 0x00 0x00 0x26
# INFO:root:设置关节弧度, 关节#4  弧度 0.9496 角度 54.4
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0xc8 0xfd 0x06 0x00 0x00 0x00 0x3b
# INFO:root:设置关节弧度, 关节#1  弧度 0.5313 角度 30.4
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x76 0xfe 0x0d 0x00 0x00 0x00 0xee
# INFO:root:设置关节弧度, 关节#2  弧度 -1.9319 角度 -110.7
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0x5c 0xff 0x0d 0x00 0x00 0x00 0xd6
# INFO:root:设置关节弧度, 关节#3  弧度 0.9934 角度 56.9
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0x8e 0xff 0x15 0x00 0x00 0x00 0x11
# INFO:root:设置关节弧度, 关节#4  弧度 0.9385 角度 53.8
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0xcf 0xfd 0x06 0x00 0x00 0x00 0x42
# INFO:root:设置关节弧度, 关节#1  弧度 0.5082 角度 29.1
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x83 0xfe 0x0d 0x00 0x00 0x00 0xfb
# INFO:root:设置关节弧度, 关节#2  弧度 -1.9565 角度 -112.1
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0x4e 0xff 0x0d 0x00 0x00 0x00 0xc8
# INFO:root:设置关节弧度, 关节#3  弧度 1.0291 角度 59.0
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0x79 0xff 0x15 0x00 0x00 0x00 0xfc
# INFO:root:设置关节弧度, 关节#4  弧度 0.9274 角度 53.1
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0xd5 0xfd 0x06 0x00 0x00 0x00 0x48
# INFO:root:设置关节弧度, 关节#1  弧度 0.4851 角度 27.8
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x90 0xfe 0x0d 0x00 0x00 0x00 0x08
# INFO:root:设置关节弧度, 关节#2  弧度 -1.9811 角度 -113.5
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0x40 0xff 0x0d 0x00 0x00 0x00 0xba
# INFO:root:设置关节弧度, 关节#3  弧度 1.0648 角度 61.0
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0x63 0xff 0x15 0x00 0x00 0x00 0xe6
# INFO:root:设置关节弧度, 关节#4  弧度 0.9163 角度 52.5
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0xdc 0xfd 0x06 0x00 0x00 0x00 0x4f
# INFO:root:设置关节弧度, 关节#1  弧度 0.4620 角度 26.5
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x9e 0xfe 0x0d 0x00 0x00 0x00 0x16
# INFO:root:设置关节弧度, 关节#2  弧度 -2.0057 角度 -114.9
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0x32 0xff 0x0d 0x00 0x00 0x00 0xac
# INFO:root:设置关节弧度, 关节#3  弧度 1.1005 角度 63.1
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0x4e 0xff 0x15 0x00 0x00 0x00 0xd1
# INFO:root:设置关节弧度, 关节#4  弧度 0.9051 角度 51.9
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0xe2 0xfd 0x06 0x00 0x00 0x00 0x55
# INFO:root:设置关节弧度, 关节#1  弧度 0.4389 角度 25.1
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0xab 0xfe 0x0d 0x00 0x00 0x00 0x23
# INFO:root:设置关节弧度, 关节#2  弧度 -2.0303 角度 -116.3
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0x24 0xff 0x0d 0x00 0x00 0x00 0x9e
# INFO:root:设置关节弧度, 关节#3  弧度 1.1362 角度 65.1
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0x39 0xff 0x15 0x00 0x00 0x00 0xbc
# INFO:root:设置关节弧度, 关节#4  弧度 0.8940 角度 51.2
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0xe9 0xfd 0x06 0x00 0x00 0x00 0x5c
# INFO:root:设置关节弧度, 关节#1  弧度 0.4158 角度 23.8
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0xb8 0xfe 0x0d 0x00 0x00 0x00 0x30
# INFO:root:设置关节弧度, 关节#2  弧度 -2.0548 角度 -117.7
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0x16 0xff 0x0d 0x00 0x00 0x00 0x90
# INFO:root:设置关节弧度, 关节#3  弧度 1.1719 角度 67.1
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0x23 0xff 0x15 0x00 0x00 0x00 0xa6
# INFO:root:设置关节弧度, 关节#4  弧度 0.8829 角度 50.6
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0xef 0xfd 0x06 0x00 0x00 0x00 0x62
# INFO:root:设置关节弧度, 关节#1  弧度 0.3927 角度 22.5
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0xc5 0xfe 0x0d 0x00 0x00 0x00 0x3d
# INFO:root:设置关节弧度, 关节#2  弧度 -2.0794 角度 -119.1
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0x08 0xff 0x0d 0x00 0x00 0x00 0x82
# INFO:root:设置关节弧度, 关节#3  弧度 1.2076 角度 69.2
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0x0e 0xff 0x15 0x00 0x00 0x00 0x91
# INFO:root:设置关节弧度, 关节#4  弧度 0.8718 角度 49.9
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0xf6 0xfd 0x06 0x00 0x00 0x00 0x69
# INFO:root:设置关节弧度, 关节#1  弧度 0.3696 角度 21.2
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0xd2 0xfe 0x0d 0x00 0x00 0x00 0x4a
# INFO:root:设置关节弧度, 关节#2  弧度 -2.1040 角度 -120.6
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0xfa 0xfe 0x0d 0x00 0x00 0x00 0x73
# INFO:root:设置关节弧度, 关节#3  弧度 1.2433 角度 71.2
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0xf8 0xfe 0x15 0x00 0x00 0x00 0x7a
# INFO:root:设置关节弧度, 关节#4  弧度 0.8607 角度 49.3
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0xfc 0xfd 0x06 0x00 0x00 0x00 0x6f
# INFO:root:设置关节弧度, 关节#1  弧度 0.3465 角度 19.9
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0xdf 0xfe 0x0d 0x00 0x00 0x00 0x57
# INFO:root:设置关节弧度, 关节#2  弧度 -2.1286 角度 -122.0
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0xec 0xfe 0x0d 0x00 0x00 0x00 0x65
# INFO:root:设置关节弧度, 关节#3  弧度 1.2790 角度 73.3
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0xe3 0xfe 0x15 0x00 0x00 0x00 0x65
# INFO:root:设置关节弧度, 关节#4  弧度 0.8495 角度 48.7
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0x03 0xfe 0x06 0x00 0x00 0x00 0x77
# INFO:root:设置关节弧度, 关节#1  弧度 0.3234 角度 18.5
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0xec 0xfe 0x0d 0x00 0x00 0x00 0x64
# INFO:root:设置关节弧度, 关节#2  弧度 -2.1532 角度 -123.4
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0xdf 0xfe 0x0d 0x00 0x00 0x00 0x58
# INFO:root:设置关节弧度, 关节#3  弧度 1.3147 角度 75.3
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0xce 0xfe 0x15 0x00 0x00 0x00 0x50
# INFO:root:设置关节弧度, 关节#4  弧度 0.8384 角度 48.0
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0x09 0xfe 0x06 0x00 0x00 0x00 0x7d
# INFO:root:设置关节弧度, 关节#1  弧度 0.3003 角度 17.2
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0xf9 0xfe 0x0d 0x00 0x00 0x00 0x71
# INFO:root:设置关节弧度, 关节#2  弧度 -2.1778 角度 -124.8
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0xd1 0xfe 0x0d 0x00 0x00 0x00 0x4a
# INFO:root:设置关节弧度, 关节#3  弧度 1.3504 角度 77.4
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0xb8 0xfe 0x15 0x00 0x00 0x00 0x3a
# INFO:root:设置关节弧度, 关节#4  弧度 0.8273 角度 47.4
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0x10 0xfe 0x06 0x00 0x00 0x00 0x84
# INFO:root:设置关节弧度, 关节#1  弧度 0.2772 角度 15.9
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x07 0xff 0x0d 0x00 0x00 0x00 0x80
# INFO:root:设置关节弧度, 关节#2  弧度 -2.2023 角度 -126.2
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0xc3 0xfe 0x0d 0x00 0x00 0x00 0x3c
# INFO:root:设置关节弧度, 关节#3  弧度 1.3861 角度 79.4
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0xa3 0xfe 0x15 0x00 0x00 0x00 0x25
# INFO:root:设置关节弧度, 关节#4  弧度 0.8162 角度 46.8
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0x16 0xfe 0x06 0x00 0x00 0x00 0x8a
# INFO:root:设置关节弧度, 关节#1  弧度 0.2541 角度 14.6
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x14 0xff 0x0d 0x00 0x00 0x00 0x8d
# INFO:root:设置关节弧度, 关节#2  弧度 -2.2269 角度 -127.6
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0xb5 0xfe 0x0d 0x00 0x00 0x00 0x2e
# INFO:root:设置关节弧度, 关节#3  弧度 1.4219 角度 81.5
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0x8e 0xfe 0x15 0x00 0x00 0x00 0x10
# INFO:root:设置关节弧度, 关节#4  弧度 0.8051 角度 46.1
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0x1d 0xfe 0x06 0x00 0x00 0x00 0x91
# INFO:root:设置关节弧度, 关节#1  弧度 0.2310 角度 13.2
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x21 0xff 0x0d 0x00 0x00 0x00 0x9a
# INFO:root:设置关节弧度, 关节#2  弧度 -2.2515 角度 -129.0
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0xa7 0xfe 0x0d 0x00 0x00 0x00 0x20
# INFO:root:设置关节弧度, 关节#3  弧度 1.4576 角度 83.5
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0x78 0xfe 0x15 0x00 0x00 0x00 0xfa
# INFO:root:设置关节弧度, 关节#4  弧度 0.7940 角度 45.5
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0x23 0xfe 0x06 0x00 0x00 0x00 0x97
# INFO:root:设置关节弧度, 关节#1  弧度 0.2079 角度 11.9
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x2e 0xff 0x0d 0x00 0x00 0x00 0xa7
# INFO:root:设置关节弧度, 关节#2  弧度 -2.2761 角度 -130.4
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0x99 0xfe 0x0d 0x00 0x00 0x00 0x12
# INFO:root:设置关节弧度, 关节#3  弧度 1.4933 角度 85.6
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0x63 0xfe 0x15 0x00 0x00 0x00 0xe5
# INFO:root:设置关节弧度, 关节#4  弧度 0.7828 角度 44.9
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0x29 0xfe 0x06 0x00 0x00 0x00 0x9d
# INFO:root:设置关节弧度, 关节#1  弧度 0.1848 角度 10.6
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x3b 0xff 0x0d 0x00 0x00 0x00 0xb4
# INFO:root:设置关节弧度, 关节#2  弧度 -2.3007 角度 -131.8
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0x8b 0xfe 0x0d 0x00 0x00 0x00 0x04
# INFO:root:设置关节弧度, 关节#3  弧度 1.5290 角度 87.6
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0x4e 0xfe 0x15 0x00 0x00 0x00 0xd0
# INFO:root:设置关节弧度, 关节#4  弧度 0.7717 角度 44.2
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0x30 0xfe 0x06 0x00 0x00 0x00 0xa4
# INFO:root:设置关节弧度, 关节#1  弧度 0.1617 角度 9.3
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x48 0xff 0x0d 0x00 0x00 0x00 0xc1
# INFO:root:设置关节弧度, 关节#2  弧度 -2.3253 角度 -133.2
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0x7d 0xfe 0x0d 0x00 0x00 0x00 0xf6
# INFO:root:设置关节弧度, 关节#3  弧度 1.5647 角度 89.6
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0x38 0xfe 0x15 0x00 0x00 0x00 0xba
# INFO:root:设置关节弧度, 关节#4  弧度 0.7606 角度 43.6
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0x36 0xfe 0x06 0x00 0x00 0x00 0xaa
# INFO:root:设置关节弧度, 关节#1  弧度 0.1386 角度 7.9
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x55 0xff 0x0d 0x00 0x00 0x00 0xce
# INFO:root:设置关节弧度, 关节#2  弧度 -2.3498 角度 -134.6
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0x6f 0xfe 0x0d 0x00 0x00 0x00 0xe8
# INFO:root:设置关节弧度, 关节#3  弧度 1.6004 角度 91.7
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0x23 0xfe 0x15 0x00 0x00 0x00 0xa5
# INFO:root:设置关节弧度, 关节#4  弧度 0.7495 角度 42.9
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0x3d 0xfe 0x06 0x00 0x00 0x00 0xb1
# INFO:root:设置关节弧度, 关节#1  弧度 0.1155 角度 6.6
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x62 0xff 0x0d 0x00 0x00 0x00 0xdb
# INFO:root:设置关节弧度, 关节#2  弧度 -2.3744 角度 -136.0
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0x61 0xfe 0x0d 0x00 0x00 0x00 0xda
# INFO:root:设置关节弧度, 关节#3  弧度 1.6361 角度 93.7
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0x0d 0xfe 0x15 0x00 0x00 0x00 0x8f
# INFO:root:设置关节弧度, 关节#4  弧度 0.7384 角度 42.3
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0x43 0xfe 0x06 0x00 0x00 0x00 0xb7
# INFO:root:设置关节弧度, 关节#1  弧度 0.0924 角度 5.3
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x70 0xff 0x0d 0x00 0x00 0x00 0xe9
# INFO:root:设置关节弧度, 关节#2  弧度 -2.3990 角度 -137.5
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0x53 0xfe 0x0d 0x00 0x00 0x00 0xcc
# INFO:root:设置关节弧度, 关节#3  弧度 1.6718 角度 95.8
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0xf8 0xfd 0x15 0x00 0x00 0x00 0x79
# INFO:root:设置关节弧度, 关节#4  弧度 0.7272 角度 41.7
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0x4a 0xfe 0x06 0x00 0x00 0x00 0xbe
# INFO:root:设置关节弧度, 关节#1  弧度 0.0693 角度 4.0
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x7d 0xff 0x0d 0x00 0x00 0x00 0xf6
# INFO:root:设置关节弧度, 关节#2  弧度 -2.4236 角度 -138.9
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0x45 0xfe 0x0d 0x00 0x00 0x00 0xbe
# INFO:root:设置关节弧度, 关节#3  弧度 1.7075 角度 97.8
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0xe3 0xfd 0x15 0x00 0x00 0x00 0x64
# INFO:root:设置关节弧度, 关节#4  弧度 0.7161 角度 41.0
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0x50 0xfe 0x06 0x00 0x00 0x00 0xc4
# INFO:root:设置关节弧度, 关节#1  弧度 0.0462 角度 2.6
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x8a 0xff 0x0d 0x00 0x00 0x00 0x03
# INFO:root:设置关节弧度, 关节#2  弧度 -2.4482 角度 -140.3
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0x37 0xfe 0x0d 0x00 0x00 0x00 0xb0
# INFO:root:设置关节弧度, 关节#3  弧度 1.7432 角度 99.9
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0xcd 0xfd 0x15 0x00 0x00 0x00 0x4e
# INFO:root:设置关节弧度, 关节#4  弧度 0.7050 角度 40.4
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0x57 0xfe 0x06 0x00 0x00 0x00 0xcb
# INFO:root:设置关节弧度, 关节#1  弧度 0.0231 角度 1.3
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0x97 0xff 0x0d 0x00 0x00 0x00 0x10
# INFO:root:设置关节弧度, 关节#2  弧度 -2.4727 角度 -141.7
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0x29 0xfe 0x0d 0x00 0x00 0x00 0xa2
# INFO:root:设置关节弧度, 关节#3  弧度 1.7789 角度 101.9
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0xb8 0xfd 0x15 0x00 0x00 0x00 0x39
# INFO:root:设置关节弧度, 关节#4  弧度 0.6939 角度 39.8
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0x5d 0xfe 0x06 0x00 0x00 0x00 0xd1
# INFO:root:设置关节弧度, 关节#1  弧度 0.0000 角度 0.0
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0xa4 0xff 0x0d 0x00 0x00 0x00 0x1d
# INFO:root:设置关节弧度, 关节#2  弧度 -2.4973 角度 -143.1
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0x1c 0xfe 0x0d 0x00 0x00 0x00 0x95
# INFO:root:设置关节弧度, 关节#3  弧度 1.8146 角度 104.0
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0xa3 0xfd 0x15 0x00 0x00 0x00 0x24
# INFO:root:设置关节弧度, 关节#4  弧度 0.6828 角度 39.1
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0x64 0xfe 0x06 0x00 0x00 0x00 0xd8
# INFO:root:设置关节弧度, 关节#1  弧度 0.0000 角度 0.0
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x00 0xa4 0xff 0x00 0x00 0x00 0x00 0x10
# INFO:root:设置关节弧度, 关节#2  弧度 -2.4973 角度 -143.1
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x01 0x1c 0xfe 0x00 0x00 0x00 0x00 0x88
# INFO:root:设置关节弧度, 关节#3  弧度 1.8146 角度 104.0
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x02 0xa3 0xfd 0x00 0x00 0x00 0x00 0x0f
# INFO:root:设置关节弧度, 关节#4  弧度 0.6828 角度 39.1
# INFO:root:串口发送请求数据 code:8
# INFO:root:数据帧内容:
# INFO:root:0x12 0x4c 0x08 0x07 0x03 0x64 0xfe 0x00 0x00 0x00 0x00 0xd2
